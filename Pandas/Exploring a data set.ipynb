# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('lending-club-reject.csv')
print(data.head(5))
# Out:
#    Amount Requested Application Date          Loan Title  Risk_Score  \
# 0           20000.0       2017-01-01  debt_consolidation         NaN
# 1           15000.0       2017-01-01    home_improvement         NaN
# 2            1000.0       2017-01-01  Debt consolidation       528.0
# 3            2500.0       2017-01-01                 car         NaN
# 4            6000.0       2017-01-01         credit_card         NaN
#
#   Debt-To-Income Ratio Zip Code State Employment Length  Policy Code
# 0                   0%    316xx    GA               n/a            0
# 1                0.58%    190xx    PA          < 1 year            0
# 2                   0%    775xx    TX          < 1 year            0
# 3                 1.7%    199xx    DE           5 years            0
# 4                2.93%    761xx    TX           5 years            0

# %%
# obtain number of rows and colums
data.shape
# Out:
# (1000, 9)

# %%
# list all columns
data.columns
# Out:
# Index(['Amount Requested', 'Application Date', 'Loan Title', 'Risk_Score',
#        'Debt-To-Income Ratio', 'Zip Code', 'State', 'Employment Length',
#        'Policy Code'],
#       dtype='object')

# %%
# know data types
data.dtypes
# Out:
# Amount Requested        float64
# Application Date         object
# Loan Title               object
# Risk_Score              float64
# Debt-To-Income Ratio     object
# Zip Code                 object
# State                    object
# Employment Length        object
# Policy Code               int64
# dtype: object

# %%
data.count()
# Out:
# Amount Requested        1000
# Application Date        1000
# Loan Title              1000
# Risk_Score               275
# Debt-To-Income Ratio    1000
# Zip Code                1000
# State                   1000
# Employment Length       1000
# Policy Code             1000
# dtype: int64

# %%
# descriptive stats
data.describe()
# Out:
#        Amount Requested  Risk_Score  Policy Code
# count       1000.000000  275.000000       1000.0
# mean       12577.550000  633.189091          0.0
# std        14359.530489   69.646033          0.0
# min         1000.000000  477.000000          0.0
# 25%         4000.000000  591.500000          0.0
# 50%        10000.000000  634.000000          0.0
# 75%        20000.000000  668.500000          0.0
# max       300000.000000  893.000000          0.0

# %%
# stats by column
data.State.describe()
# Out:
# count     1000
# unique      49
# top         FL
# freq        84
# Name: State, dtype: object

# %%
# unique entries in a column
data.State.unique()
# Out:
# array(['GA', 'PA', 'TX', 'DE', 'AL', 'IN', 'SC', 'WA', 'AZ', 'NY', 'WI',
#        'VA', 'CA', 'FL', 'MA', 'ND', 'MI', 'CO', 'OR', 'MO', 'AK', 'AR',
#        'LA', 'NJ', 'OH', 'NC', 'MN', 'IL', 'TN', 'KY', 'NM', 'CT', 'NV',
#        'HI', 'ME', 'DC', 'ID', 'NE', 'MD', 'WY', 'NH', 'OK', 'MS', 'MT',
#        'UT', 'KS', 'VT', 'RI', 'SD'], dtype=object)

# %%
data.groupby(['State']).count()
# Out:
#        Amount Requested  Application Date  Loan Title  Risk_Score  \
# State
# AK                    3                 3           3           0
# AL                   31                31          31           8
# AR                   13                13          13           3
# AZ                   17                17          17           7
# CA                   73                73          73          20
# CO                   18                18          18           4
# CT                   17                17          17           6
# DC                    2                 2           2           0
# DE                    4                 4           4           1
# FL                   84                84          84          19
# GA                   41                41          41           9
# HI                    7                 7           7           2
# ID                    1                 1           1           0
# ...

# %%
data.groupby(['State']).count().sort_values('Amount Requested')
# Out:
#        Amount Requested  Application Date  Loan Title  Risk_Score  \
# State
# VT                    1                 1           1           1
# ID                    1                 1           1           0
# WY                    2                 2           2           1
# MT                    2                 2           2           0
# DC                    2                 2           2           0
# SD                    3                 3           3           0
# KS                    3                 3           3           2
# AK                    3                 3           3           0
# DE                    4                 4           4           1
# NM                    4                 4           4           2
# ND                    5                 5           5           1
# NE                    5                 5           5           0
# ME                    6                 6           6           2
# ...

# %%
data.groupby(['State']).count().sort_values('Employment Length',ascending = False)
# Out:
#        Amount Requested  Application Date  Loan Title  Risk_Score  \
# State
# FL                   84                84          84          19
# CA                   73                73          73          20
# TX                   72                72          72          32
# NY                   72                72          72          21
# OH                   42                42          42           6
# GA                   41                41          41           9
# MI                   38                38          38          11
# PA                   38                38          38          16
# NC                   37                37          37           6
# VA                   36                36          36           6
# AL                   31                31          31           8
# IL                   31                31          31           6
# NJ                   28                28          28           5
# ...
